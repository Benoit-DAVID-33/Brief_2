# %%
import pandas as pd
import matplotlib.pyplot as plt
data_2021_2023 = pd.read_csv('salaries.csv')
data_2021_2023.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023               SE              FT  Machine Learning Engineer
# 1       2023               MI              FT               BI Developer
# 2       2023               MI              FT               BI Developer
# 3       2023               MI              FT               Data Analyst
# 4       2023               MI              FT               Data Analyst
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   65000             EUR          70179                 IT           100
# 1  110000             USD         110000                 US             0
# 2   75000             USD          75000                 US             0
# 3   43000             EUR          46426                 SI             0
# 4   36000             EUR          38868                 SI             0
#
#   company_location company_size
# 0               US            L
# ...

# %%
data_2017_2020 = pd.read_csv('2019_Data_Professional_Salary_Survey_Responses.csv')
data_2017_2020.head(len(data_2017_2020))
# Out:
#       Survey Year          Timestamp SalaryUSD         Country PostalCode  \
# 0            2017   1/5/2017 5:10:20    200000   United States  Not Asked
# 1            2017   1/5/2017 5:26:23     61515  United Kingdom  Not Asked
# 2            2017   1/5/2017 5:32:57     95000         Germany  Not Asked
# 3            2017   1/5/2017 5:33:03     56000  United Kingdom  Not Asked
# 4            2017   1/5/2017 5:34:33     35000          France  Not Asked
# ...           ...                ...       ...             ...        ...
# 6888         2019   1/4/2019 6:16:12     32000         Hungary        NaN
# 6889         2019   1/4/2019 6:18:47     32000         Hungary        NaN
# 6890         2019   1/4/2019 9:06:05     40000        Portugal       1000
# 6891         2019  1/4/2019 10:06:24    130000   United States      49506
# 6892         2019  1/5/2019 18:25:21     84500          Canada    N2K 4L5
#
#            PrimaryDatabase  YearsWithThisDatabase  \
# ...

# %%
data_2021_2023_copy = data_2021_2023.copy()
data_2021_2023_copy = data_2021_2023_copy.drop(["company_size", "remote_ratio", 
                                                "salary_currency", "company_size", "salary"], axis=1)
data_2021_2023_copy.head()
print(data_2021_2023_copy.dtypes)
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary_in_usd          int64
# employee_residence    object
# company_location      object
# dtype: object

# %%
data_2017_2020_copy = data_2017_2020.copy()  
data_2017_2020_copy = data_2017_2020_copy.drop([ 'Timestamp', 'PostalCode',
       'PrimaryDatabase', 'YearsWithThisDatabase', 'OtherDatabases',
        'ManageStaff', 'YearsWithThisTypeOfJob',
       'HowManyCompanies', 'OtherPeopleOnYourTeam', 'CompanyEmployeesOverall',
       'DatabaseServers', 'Education', 'EducationIsComputerRelated',
       'Certifications', 'HoursWorkedPerWeek', 'TelecommuteDaysPerWeek',
       'PopulationOfLargestCityWithin20Miles',
       'LookingForAnotherJob', 'CareerPlansThisYear', 'Gender',
       'OtherJobDuties', 'KindsOfTasksPerformed', 'Counter', 'EmploymentSector'], axis=1)
data_2017_2020_copy.head()
# print(data_2017_2020_copy.dtypes)
# Out:
#    Survey Year SalaryUSD         Country  \
# 0         2017    200000   United States
# 1         2017     61515  United Kingdom
# 2         2017     95000         Germany
# 3         2017     56000  United Kingdom
# 4         2017     35000          France
#
#                                     EmploymentStatus JobTitle
# 0                                 Full time employee      DBA
# 1                                 Full time employee      DBA
# 2                                 Full time employee    Other
# 3                                 Full time employee      DBA
# 4  Full time employee of a consulting/contracting...      DBA

# %%
# python
data_2017_2020_copy.isna().sum()
data_2017_2020_copy.isnull().sum()
# Out:
# Survey Year         0
# SalaryUSD           0
# Country             0
# EmploymentStatus    0
# JobTitle            0
# dtype: int64

# %%
data_2021_2023_copy.isna().sum()
data_2021_2023_copy.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary_in_usd         0
# employee_residence    0
# company_location      0
# dtype: int64

# %%
unique_countries = data_2017_2020_copy['Country'].unique()
print("Pays uniques :")
for country in unique_countries:
    print(country)
# Out:
# Pays uniques :
# United States
# United Kingdom
# Germany
# France
# Netherlands
# Belgium
# Canada
# Poland
# Ukraine
# Australia
# India
# Portugal
# South Africa
# Greece
# Israel
# Sweden
# Spain
# Norway
# Jersey
# Argentina
# Russia
# Switzerland
# Denmark
# Ireland
# Italy
# Mexico
# Albania
# Brazil
# Romania
# Uganda
# Slovenia
# Bulgaria
# Turkey
# Lithuania
# New Zealand
# Czech Republic
# Croatia
# Finland
# Austria
# Hungary
# El Salvador
# Bolivia
# Vietnam
# China
# Luxembourg
# Iceland
# Serbia and Montenegro
# Jamaica
# Moldova
# Saudi Arabia
# Paraguay
# Guernsey
# Hong Kong
# Venezuela
# Philippines
# Malaysia
# Macedonia
# Bermuda
# Ecuador
# Nicaragua
# Puerto Rico
# Peru
# Singapore
# Kenya
# Syria
# Colombia
# United Arab Emirates
# Costa Rica
# Cayman Islands
# Indonesia
# Bahrain
# Thailand
# Slovakia
# Pakistan
# Malta
# Jordan
# Belarus
# Estonia
# Latvia
# Nepal
# Ghana
# Dominican Republic
# Uruguay
# Guatemala
# Taiwan

# %%
data_2021_2023_copy.isna().sum()
data_2021_2023_copy.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary_in_usd         0
# employee_residence    0
# company_location      0
# dtype: int64

# %%
# unique_countries = data_2021_2023_copy['company_location'].unique()
# print("Pays uniques :")
# for country in unique_countries:
#     print(country)

# %%
# data_2021_2023_copy['company_location'] = data_2021_2023_copy['company_location']\
#     .replace('US', 'United States')\
#     .replace('SI', 'Singapour')\
#     .replace('IN', 'India')\
#     .replace('GB', 'United Kingdom')\
#     .replace('RO', 'Roumania')\
#     .replace('ES', 'Spain')\
#     .replace('CA', 'Canada')\
#     .replace('GR', 'Greece')\
#     .replace('CO', 'Colombia')\
#     .replace('PT', 'Portugal')\
#     .replace('UA', 'Ukraine')\
#     .replace('FR', 'France')\
#     .replace('NL', 'Netherlands')\
#     .replace('LV', 'Latvia')\
#     .replace('LV', 'Latvia')\
#     .replace('LV', 'Latvia')\
#     .replace('LV', 'Latvia')\
#     .replace('LV', 'Latvia')\
#     .replace('LV', 'Latvia')\
    
    
    
# data_2021_2023_copy.head(20)

# %%
import pycountry

df = pd.DataFrame(data_2021_2023_copy)

def get_country_name(initial):
    try:
        country = pycountry.countries.get(alpha_2=initial)
        return country.name
    except AttributeError:
        return initial
    
df['company_location'] = df['company_location'].apply(get_country_name)
df.rename(columns={'company_location': 'Country'}, inplace=True)

df['employee_residence'] = df['employee_residence'].apply(get_country_name)

df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT  Machine Learning Engineer
# 1          2023               MI              FT               BI Developer
# 2          2023               MI              FT               BI Developer
# 3          2023               MI              FT               Data Analyst
# 4          2023               MI              FT               Data Analyst
# ...         ...              ...             ...                        ...
# 8097       2020               SE              FT             Data Scientist
# 8098       2021               MI              FT   Principal Data Scientist
# 8099       2020               EN              FT             Data Scientist
# 8100       2020               EN              CT      Business Data Analyst
# 8101       2021               SE              FT       Data Science Manager
#
#       salary_in_usd employee_residence        Country
# ...

# %%
import pycountry

df = pd.DataFrame(data_2021_2023_copy)

def get_country_name(initial):
    try:
        country = pycountry.countries.get(alpha_2=initial)
        return country.name
    except AttributeError:
        return initial 
    
df['company_location'] = df['company_location'].apply(get_country_name)
df.rename(columns={'company_location': 'Country'}, inplace=True)

df['employee_residence'] = df['employee_residence'].apply(get_country_name)


# experience_level

df['experience_level'] = df['experience_level']\
    .replace('EN', 'Junior')\
    .replace('MI', 'Internmediate')\
    .replace('SE', 'Expert')\
    .replace('EX', 'Director')
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023           Expert              FT  Machine Learning Engineer
# 1          2023    Internmediate              FT               BI Developer
# 2          2023    Internmediate              FT               BI Developer
# 3          2023    Internmediate              FT               Data Analyst
# 4          2023    Internmediate              FT               Data Analyst
# ...         ...              ...             ...                        ...
# 8097       2020           Expert              FT             Data Scientist
# 8098       2021    Internmediate              FT   Principal Data Scientist
# 8099       2020           Junior              FT             Data Scientist
# 8100       2020           Junior              CT      Business Data Analyst
# 8101       2021           Expert              FT       Data Science Manager
#
#       salary_in_usd employee_residence        Country
# ...

# %%
data_2021_2023_copy.isna().sum()
data_2021_2023_copy.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary_in_usd         0
# employee_residence    0
# company_location      0
# dtype: int64

# %%
data = pd.read_csv('Salary_2017_2020.csv')
data.head(20)
# Out:
#     Unnamed: 0  Survey Year SalaryUSD         Country EmploymentStatus  \
# 0            0         2017    200000   United States        Full time
# 1            1         2017     61515  United Kingdom        Full time
# 2            2         2017     95000         Germany        Full time
# 3            3         2017     56000  United Kingdom        Full time
# 4            4         2017     35000          France        Full time
# 5            5         2017    215000  United Kingdom        Freelance
# 6            6         2017     75000         Germany        Full time
# 7            7         2017     47000     Netherlands        Full time
# 8            9         2017     51652  United Kingdom        Full time
# 9           10         2017     37500     Netherlands        Full time
# 10          11         2017     60000         Belgium        Full time
# 11          12         2017    137500   United States        Full time
# ...

# %%
data = data_2021_2023[['experience_level', 'salary']][:10]

plt.figure(figsize=(12, 8))
plt.scatter(data['experience_level'], data['salary'])
plt.title("Répartition des salaires en fonction du niveau d'expérience pour un échantillon de données")
plt.xlabel("Niveau d'expérience")
plt.ylabel("Salaire")

plt.show()
